# %% [markdown]
# <a id = "0"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">CRISP-DM </span></h1>
#
# ![image.png](attachment:09b0a6ba-e18c-4288-a856-9854b2e17a1c.png)
#
# ***CRISP-DM:*** *Veri Bilimi süreçlerinin iş dünyasındaki ele alınışını ifade ediyor. Sıfırdan bir ürün geliştirme işlemini genelde şirketler bu döngüyü takip ederek gerçekleştiriyor.*
#
# <a id = "1"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">1- İş Anlayışı </span></h1>
#
# *CRISP-DM aşamalarından biri olan "İş Anlayışı"na bakalım önce.*
# ![image.png](attachment:4f43c960-885c-46bd-870d-8b43a3e074a6.png)
#
# <a id = "2"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">2- Veriyi Anlamak </span></h1>
#
# *CRISP-DM aşamalarından biri olan "veriyi anlamak" başlığını açıklayalım.*
#
# ![image.png](attachment:6a1e88eb-afd3-44b4-aabc-4dc806567e8f.png)
# ![image.png](attachment:dbcfdc39-7a82-447b-8626-67f3245d2b9d.png)
#
# <a id = "3"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">3- Verinin Hazırlanması </span></h1>
#
# *CRISP-DM adımlarından biri olan "verinin hazırlanması" kısmına değinelim.*
#
# ![image.png](attachment:a7c1b921-ee29-49df-b875-cbaab336d964.png)
#
# *Bu aşamada modelleme basamağına geçmeden önce veri setimizdeki NA yani boş değerleri, aykırı (uç) değerleri,  bozuk/yanlış değerleri gidermemiz, veriyi iyi bir şekilde hazırlamamız gerekiyor.*
#
# ![image.png](attachment:a67b8143-e0c0-40bc-a270-cbb4b5427d5e.png)
#
# *Evet gördüğünüz gibi verideki bozukluklar giderildi. Şimdi veriyi modele verebiliriz diyebiliriz.*
#
# <a id = "4"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">4- Modelleme </span></h1>
#
# *CRISP-DM adımlarından biri olan "modelleme" adımı ele alalım.*
#
# ![image.png](attachment:2621c046-a23d-457e-b63d-0a748ca68e20.png)
# *Resimde de görüldüğü üzere modelleme aşamasında örnek bir model kurduk ve tahmini araç fiyatı belirledik.*
#
#
# <a id = "5"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">5- Değerlendirme </span></h1>
#
# *CRISP-DM adımlarından biri olan "değerlendirme" adımını açıklayalım.*
#
# ![image.png](attachment:10280be5-3839-4e90-818f-45e1907365ee.png)
#
# *Karşılaştırılması, performansının değerlendirilmesi, testler yapılması vs. hepsi bu adımda yapılır.*
# > *Veri Bilimci’nin amacı tahmin edilen değer ile gerçek değerler arasındaki farkın minimum olmasını sağlamaktır.*
#
# <a id = "6"></a><h1 id="Introduction"><span class="label label-default" style="background-color:#2E86C1; border-radius:8px; font-weight: bold; font-family:Verdana; font-size:22px; color:#FBFAFC; ">6- Kullanıma Sokma </span></h1>
#
# *CRISP-DM adımlarından biri olan "kullanıma sokma" adımını ele alalım.*
#
# *Model başarılı değerlendirme işleminden sonra artık kurmuş olduğumuz bu modeli, bu örnek senaryo kapsamında örneğin web sitemize entegre edebiliriz ve kullanıcılara açabiliriz.*
